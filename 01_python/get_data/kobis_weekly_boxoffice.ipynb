# %%
import requests

key='e4c27c6869d8b4d332b852773e24f030'


week = ['20181111', '20181118', '20181125', '20181202', '20181209', '20181216', '20181223', '20181230', '20190106', '20190113']

results={}
for i in week:
    URL = f'https://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={i}&weekGb=0'
    raw_data = requests.get(URL)
    data = raw_data.json()
    data = data['boxOfficeResult']['weeklyBoxOfficeList']
    for j in range(10):
        
        results[data[j]['movieNm']] = {
        'movieCd' : data[j]['movieCd'],

        'audiAcc' : data[j]['audiAcc'],
        'date' : str(i)
        }
        
print(results)
# Out:
# {'완벽한 타인': {'movieCd': '20177538', 'audiAcc': '5270621', 'date': '20181216'}, '보헤미안 랩소디': {'movieCd': '20185485', 'audiAcc': '9785643', 'date': '20190113'}, '동네사람들': {'movieCd': '20170513', 'audiAcc': '445625', 'date': '20181118'}, '바울': {'movieCd': '20181171', 'audiAcc': '229837', 'date': '20181202'}, '창궐': {'movieCd': '20174981', 'audiAcc': '1588443', 'date': '20181111'}, '해리포터와 마법사의 돌': {'movieCd': '20010291', 'audiAcc': '259733', 'date': '20181111'}, '여곡성': {'movieCd': '20179006', 'audiAcc': '55997', 'date': '20181111'}, '벽 속에 숨은 마법시계': {'movieCd': '20181404', 'audiAcc': '211233', 'date': '20181111'}, '스타 이즈 본': {'movieCd': '20180523', 'audiAcc': '458917', 'date': '20181111'}, '구스범스: 몬스터의 역습': {'movieCd': '20182693', 'audiAcc': '21400', 'date': '20181111'}, '신비한 동물들과 그린델왈드의 범죄': {'movieCd': '20176814', 'audiAcc': '2403686', 'date': '20181209'}, '번 더 스테이지: 더 무비': {'movieCd': '20183050', 'audiAcc': '298402', 'date': '20181125'}, '성난황소': {'movieCd': '20184481', 'audiAcc': '1567264', 'date': '20181209'}, '출국': {'movieCd': '20182935', 'audiAcc': '71407', 'date': '20181125'}, '너의 췌장을 먹고 싶어': {'movieCd': '20186822', 'audiAcc': '48910', 'date': '20181125'}, '해피 투게더': {'movieCd': '20189869', 'audiAcc': '15745', 'date': '20181118'}, '베일리 어게인': {'movieCd': '20183073', 'audiAcc': '78439', 'date': '20181202'}, '툴리': {'movieCd': '20182669', 'audiAcc': '24325', 'date': '20181125'}, '국가부도의 날': {'movieCd': '20177552', 'audiAcc': '3723915', 'date': '20181223'}, '후드': {'movieCd': '20181905', 'audiAcc': '276658', 'date': '20181209'}, '거미줄에 걸린 소녀': {'movieCd': '20183007', 'audiAcc': '25172', 'date': '20181202'}, '투 프렌즈': {'movieCd': '20182966', 'audiAcc': '20419', 'date': '20181202'}, '도어락': {'movieCd': '20179230', 'audiAcc': '1546002', 'date': '20181223'}, '호두까기 인형과 4개의 왕국': {'movieCd': '20189843', 'audiAcc': '408425', 'date': '20181216'}, '모털 엔진': {'movieCd': '20178825', 'audiAcc': '262070', 'date': '20181216'}, '런닝맨 : 풀룰루의 역습': {'movieCd': '20183745', 'audiAcc': '180709', 'date': '20181216'}, '스파이더맨: 뉴 유니버스': {'movieCd': '20183238', 'audiAcc': '628327', 'date': '20181230'}, '부탁 하나만 들어줘': {'movieCd': '20182082', 'audiAcc': '87501', 'date': '20181216'}, '스윙키즈': {'movieCd': '20175547', 'audiAcc': '1462874', 'date': '20190113'}, '아쿠아맨': {'movieCd': '20180290', 'audiAcc': '4920735', 'date': '20190113'}, '마약왕': {'movieCd': '20168773', 'audiAcc': '1787838', 'date': '20181230'}, '그린치': {'movieCd': '20182421', 'audiAcc': '543815', 'date': '20190106'}, '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~': {'movieCd': '20183479', 'audiAcc': '259753', 'date': '20181230'}, '극장판 포켓몬스터 모두의 이야기': {'movieCd': '20183375', 'audiAcc': '86997', 'date': '20181223'}, '범블비': {'movieCd': '20186281', 'audiAcc': '1553491', 'date': '20190113'}, 'PMC: 더 벙커': {'movieCd': '20170658', 'audiAcc': '1665204', 'date': '20190113'}, '점박이 한반도의 공룡2 : 새로운 낙원': {'movieCd': '20183785', 'audiAcc': '521053', 'date': '20190106'}, '주먹왕 랄프 2: 인터넷 속으로': {'movieCd': '20189463', 'audiAcc': '1342315', 'date': '20190113'}, '언니': {'movieCd': '20184187', 'audiAcc': '172340', 'date': '20190106'}, '말모이': {'movieCd': '20184105', 'audiAcc': '1185368', 'date': '20190113'}, '내안의 그놈': {'movieCd': '20176251', 'audiAcc': '765383', 'date': '20190113'}, '극장판 공룡메카드: 타이니소어의 섬': {'movieCd': '20183915', 'audiAcc': '289873', 'date': '20190113'}, '그린 북': {'movieCd': '20184574', 'audiAcc': '99569', 'date': '20190113'}}

# %%
import csv

f = open('boxoffice.csv', 'w+', encoding='utf-8', newline = '')

writer = csv.writer(f)

writer.writerow(
        ['영화 코드', '영화명', '누적 관객수', '기준일']
    )

f.close()

# %%
f = open('boxoffice.csv', 'a+', encoding='utf-8', newline = '')

writer = csv.writer(f)

for k, v in results.items():
    writer.writerow(
        [results[k]['movieCd'], k, results[k]['audiAcc'], results[k]['date']]
    )

f.close()

# %%
movie_code=[]
for i in results:
    movie_code += [results[i]['movieCd']]

# %%
movie_code
# Out:
# ['20177538',
#  '20185485',
#  '20170513',
#  '20181171',
#  '20174981',
#  '20010291',
#  '20179006',
#  '20181404',
#  '20180523',
#  '20182693',
#  '20176814',
#  '20183050',
#  '20184481',
#  '20182935',
#  '20186822',
#  '20189869',
#  '20183073',
#  '20182669',
#  '20177552',
#  '20181905',
#  '20183007',
#  '20182966',
#  '20179230',
#  '20189843',
#  '20178825',
#  '20183745',
#  '20183238',
#  '20182082',
#  '20175547',
#  '20180290',
#  '20168773',
#  '20182421',
#  '20183479',
#  '20183375',
#  '20186281',
#  '20170658',
#  '20183785',
#  '20189463',
#  '20184187',
#  '20184105',
#  '20176251',
#  '20183915',
#  '20184574']

# %%
detail_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd=20183915'

detail_raw_data = requests.get(detail_url)
detail_data=detail_raw_data.json()

detail_data = detail_data['movieInfoResult']['movieInfo']

detail

# %%
detail_data
# Out:
# {'movieCd': '20183915',
#  'movieNm': '극장판 공룡메카드: 타이니소어의 섬',
#  'movieNmEn': '',
#  'movieNmOg': '',
#  'showTm': '70',
#  'prdtYear': '2018',
#  'openDt': '20190110',
#  'prdtStatNm': '개봉',
#  'typeNm': '장편',
#  'nations': [{'nationNm': '한국'}],
#  'genres': [{'genreNm': '애니메이션'}],
#  'directors': [{'peopleNm': '최신규', 'peopleNmEn': 'CHOE Shin-gyu'},
#   {'peopleNm': '유재운', 'peopleNmEn': ''}],
#  'actors': [],
#  'showTypes': [{'showTypeGroupNm': '2D', 'showTypeNm': '디지털'}],
#  'companys': [{'companyCd': '20141337',
#    'companyNm': '(주)초이락컨텐츠팩토리',
#    'companyNmEn': 'CHOIROCK CONTENTS FACTORY Co.,Ltd.',
#    'companyPartNm': '제작사'},
#   {'companyCd': '20100932',
#    'companyNm': '(주)넥스트엔터테인먼트월드(NEW)',
#    'companyNmEn': 'Next Entertainment World',
#    'companyPartNm': '배급사'}],
#  'audits': [{'auditNo': '2018-MF02159', 'watchGradeNm': '전체관람가'}],
#  'staffs': []}

# %%
# detail_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd={code}'
# 결과
# 영화별로 다음과 같은 내용을 저장합니다. 
# 영화 대표코드, 영화명(국문), 영화명(영문), 영화명(원문) , 개봉연도, 상시간, 장르, 감독 명, 관람등급, 
# 배우1, 배우2, 배우3 배우의 경우 최대 3명입니다. 영화에 따라 1~2명일 수도 있습니다. 
# 해당 결과를 movie.csv에 저장합니다. 

detail_result = {}
for x in movie_code:
    detail_url = f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd={x}'

    detail_raw_data = requests.get(detail_url)
    detail_data=detail_raw_data.json()

    detail_data = detail_data['movieInfoResult']['movieInfo']


    
        


#     for i in range(len(movie_code)):
        

    detail_result[detail_data['movieNm']] = {
        'movieCd' : detail_data['movieCd'],
        'movieNm' : detail_data['movieNm'],
        'movieNmEn' : detail_data['movieNmEn'],
        'movieNmOg' : detail_data['movieNmOg'],
        'openDt' : detail_data['openDt'],
        'showTm' : detail_data['showTm'],
        'genres' : detail_data['genres'][0]['genreNm'],
        'directors' : detail_data['directors'][0]['peopleNm'],
        'watchGradeNm' : detail_data['audits'][0]['watchGradeNm'],
        'actors' : detail_data['actors']
    }


    
    

    
detail_result
# Out:
# {'완벽한 타인': {'movieCd': '20177538',
#   'movieNm': '완벽한 타인',
#   'movieNmEn': 'Intimate Strangers',
#   'movieNmOg': '',
#   'openDt': '20181031',
#   'showTm': '115',
#   'genres': '드라마',
#   'directors': '이재규',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '유해진',
#     'peopleNmEn': 'YOO Hae-jin',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '조진웅',
#     'peopleNmEn': 'CHO Jin-woong',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '이서진',
#     'peopleNmEn': 'LEE Seo-jin',
#     'cast': '준모',
#     'castEn': ''},
#    {'peopleNm': '염정아', 'peopleNmEn': 'YUM Jung-ah', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김지수', 'peopleNmEn': 'KIM Ji-soo', 'cast': '', 'castEn': ''},
#    {'peopleNm': '송하윤', 'peopleNmEn': 'SONG Ha-yoon', 'cast': '', 'castEn': ''},
#    {'peopleNm': '윤경호', 'peopleNmEn': '', 'cast': '', 'castEn': ''},
#    {'peopleNm': '지우', 'peopleNmEn': 'Ji-woo', 'cast': '', 'castEn': ''}]},
#  '보헤미안 랩소디': {'movieCd': '20185485',
#   'movieNm': '보헤미안 랩소디',
#   'movieNmEn': 'Bohemian Rhapsody',
#   'movieNmOg': '',
#   'openDt': '20181031',
#   'showTm': '134',
#   'genres': '드라마',
#   'directors': '브라이언 싱어',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '레미 맬렉',
#     'peopleNmEn': 'Rami Malek',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '조셉 마젤로',
#     'peopleNmEn': 'Joseph Mazzello',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '마이크 마이어스',
#     'peopleNmEn': 'Mike Myers',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '루시 보인턴',
#     'peopleNmEn': 'Lucy Boynton',
#     'cast': '',
#     'castEn': ''}]},
#  '동네사람들': {'movieCd': '20170513',
#   'movieNm': '동네사람들',
#   'movieNmEn': '',
#   'movieNmOg': '',
#   'openDt': '20181107',
#   'showTm': '99',
#   'genres': '액션',
#   'directors': '임진순',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '마동석',
#     'peopleNmEn': 'Don LEE',
#     'cast': '역기철',
#     'castEn': ''},
#    {'peopleNm': '김새론',
#     'peopleNmEn': 'KIM Sae-ron',
#     'cast': '강유진',
#     'castEn': ''},
#    {'peopleNm': '이상엽',
#     'peopleNmEn': 'LEE Sang-yeob',
#     'cast': '지성',
#     'castEn': ''},
#    {'peopleNm': '진선규',
#     'peopleNmEn': 'JIN Seon-kyu',
#     'cast': '병두',
#     'castEn': ''},
#    {'peopleNm': '장광', 'peopleNmEn': 'JANG Kwang', 'cast': '기태', 'castEn': ''},
#    {'peopleNm': '신세휘', 'peopleNmEn': '', 'cast': '수연', 'castEn': ''},
#    {'peopleNm': '오희준', 'peopleNmEn': 'OH Hee-jun', 'cast': '동수', 'castEn': ''},
#    {'peopleNm': '배진아', 'peopleNmEn': '', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이광기', 'peopleNmEn': '', 'cast': '지성대역', 'castEn': ''},
#    {'peopleNm': '이상훈', 'peopleNmEn': '', 'cast': '형사1', 'castEn': ''}]},
#  '바울': {'movieCd': '20181171',
#   'movieNm': '바울',
#   'movieNmEn': 'Paul, Apostle Of Christ',
#   'movieNmOg': '',
#   'openDt': '20181031',
#   'showTm': '107',
#   'genres': '드라마',
#   'directors': '앤드류 하얏트',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '제임스 폴크너',
#     'peopleNmEn': 'James Faulkner',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '제임스 카비젤',
#     'peopleNmEn': 'James Caviezel',
#     'cast': '',
#     'castEn': ''}]},
#  '창궐': {'movieCd': '20174981',
#   'movieNm': '창궐',
#   'movieNmEn': 'Rampant',
#   'movieNmOg': '',
#   'openDt': '20181025',
#   'showTm': '121',
#   'genres': '사극',
#   'directors': '김성훈',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '현빈',
#     'peopleNmEn': 'HYUN Bin',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '장동건',
#     'peopleNmEn': 'JANG Dong-gun',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '조우진', 'peopleNmEn': 'JO Woo-jin', 'cast': '', 'castEn': ''},
#    {'peopleNm': '정만식', 'peopleNmEn': 'JUNG Man-sik', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이선빈', 'peopleNmEn': 'LEE Seon-bin', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김의성', 'peopleNmEn': 'KIM Eui-sung', 'cast': '', 'castEn': ''},
#    {'peopleNm': '조달환', 'peopleNmEn': 'CHO Dal-hwan', 'cast': '', 'castEn': ''},
#    {'peopleNm': '박진우', 'peopleNmEn': 'PARK Jin-woo', 'cast': '', 'castEn': ''},
#    {'peopleNm': '서지혜',
#     'peopleNmEn': 'SEO Ji-hye',
#     'cast': '조씨(조복실)',
#     'castEn': ''},
#    {'peopleNm': '한지은', 'peopleNmEn': 'HAN Ji-eun', 'cast': '', 'castEn': ''},
#    {'peopleNm': '공정환',
#     'peopleNmEn': 'GONG Jung-hwan',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '김태우', 'peopleNmEn': 'KIM Tae-woo', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이승일', 'peopleNmEn': '', 'cast': '내금위2', 'castEn': ''},
#    {'peopleNm': '이동훈', 'peopleNmEn': '', 'cast': '야귀', 'castEn': ''},
#    {'peopleNm': '이상준', 'peopleNmEn': '', 'cast': '내금위4', 'castEn': ''},
#    {'peopleNm': '이상훈', 'peopleNmEn': '', 'cast': '야귀', 'castEn': ''},
#    {'peopleNm': '이승주', 'peopleNmEn': '', 'cast': '야귀', 'castEn': ''},
#    {'peopleNm': '배정환', 'peopleNmEn': '', 'cast': '스님2', 'castEn': ''},
#    {'peopleNm': '이우성', 'peopleNmEn': '', 'cast': '야귀', 'castEn': ''},
#    {'peopleNm': '이우정', 'peopleNmEn': '', 'cast': '야귀', 'castEn': ''},
#    {'peopleNm': '이유진', 'peopleNmEn': '', 'cast': '야귀', 'castEn': ''},
#    {'peopleNm': '이재남', 'peopleNmEn': '', 'cast': '이청대역', 'castEn': ''},
#    {'peopleNm': '이정민',
#     'peopleNmEn': 'LEE Jung-min',
#     'cast': '동궁나인3',
#     'castEn': ''},
#    {'peopleNm': '이정민',
#     'peopleNmEn': 'LEE Jung-min',
#     'cast': '청나라가인2',
#     'castEn': ''},
#    {'peopleNm': '김주혁', 'peopleNmEn': 'KIM Joo-hyuk', 'cast': '', 'castEn': ''},
#    {'peopleNm': '서지은', 'peopleNmEn': '', 'cast': '야귀', 'castEn': ''}]},
#  '해리포터와 마법사의 돌': {'movieCd': '20010291',
#   'movieNm': '해리포터와 마법사의 돌',
#   'movieNmEn': 'Harry Potter And The Socrerers Stone',
#   'movieNmOg': '',
#   'openDt': '20011213',
#   'showTm': '152',
#   'genres': '가족',
#   'directors': '크리스 콜럼버스',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '다니엘 래드클리프',
#     'peopleNmEn': 'Daniel Radcliffe',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '엠마 왓슨',
#     'peopleNmEn': 'Emma Watson',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '루퍼트 그린트',
#     'peopleNmEn': 'Rupert Grint',
#     'cast': '',
#     'castEn': ''}]},
#  '여곡성': {'movieCd': '20179006',
#   'movieNm': '여곡성',
#   'movieNmEn': 'The Wrath',
#   'movieNmOg': '',
#   'openDt': '20181108',
#   'showTm': '94',
#   'genres': '공포(호러)',
#   'directors': '유영선',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '홍예리',
#     'peopleNmEn': 'HONG Yae-ree',
#     'cast': '비류',
#     'castEn': ''},
#    {'peopleNm': '서영희',
#     'peopleNmEn': 'SEO Young-hee',
#     'cast': '신씨부인',
#     'castEn': ''},
#    {'peopleNm': '손나은', 'peopleNmEn': 'SON Na-eun', 'cast': '옥분', 'castEn': ''},
#    {'peopleNm': '이태리', 'peopleNmEn': '', 'cast': '해천비', 'castEn': ''},
#    {'peopleNm': '박민지',
#     'peopleNmEn': 'PARK Min-ji',
#     'cast': '월아',
#     'castEn': ''},
#    {'peopleNm': '최홍일', 'peopleNmEn': '', 'cast': '이경진 대감', 'castEn': ''},
#    {'peopleNm': '손성윤', 'peopleNmEn': '', 'cast': '경란', 'castEn': ''},
#    {'peopleNm': '이재아', 'peopleNmEn': '', 'cast': '영숙', 'castEn': ''},
#    {'peopleNm': '김호창', 'peopleNmEn': '', 'cast': '명규', 'castEn': ''},
#    {'peopleNm': '이해나', 'peopleNmEn': '', 'cast': '예산댁', 'castEn': ''},
#    {'peopleNm': '이재구',
#     'peopleNmEn': 'LEE Jae-goo',
#     'cast': '장서방',
#     'castEn': ''},
#    {'peopleNm': '이설희', 'peopleNmEn': '', 'cast': '악사2', 'castEn': ''},
#    {'peopleNm': '이승현', 'peopleNmEn': '', 'cast': '동자승2', 'castEn': ''},
#    {'peopleNm': '이승훈', 'peopleNmEn': '', 'cast': '주지승', 'castEn': ''},
#    {'peopleNm': '서영희',
#     'peopleNmEn': 'SEO Young-hee',
#     'cast': '신씨',
#     'castEn': ''}]},
#  '벽 속에 숨은 마법시계': {'movieCd': '20181404',
#   'movieNm': '벽 속에 숨은 마법시계',
#   'movieNmEn': 'The house with a clock in its walls',
#   'movieNmOg': '',
#   'openDt': '20181031',
#   'showTm': '105',
#   'genres': '판타지',
#   'directors': '일라이 로스',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '잭 블랙',
#     'peopleNmEn': 'Jack Black',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '케이트 블란쳇',
#     'peopleNmEn': 'Cate Blanchett',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '오웬 바카로',
#     'peopleNmEn': 'Owen Vaccaro',
#     'cast': '',
#     'castEn': ''}]},
#  '스타 이즈 본': {'movieCd': '20180523',
#   'movieNm': '스타 이즈 본',
#   'movieNmEn': 'A Star Is Born',
#   'movieNmOg': '',
#   'openDt': '20181009',
#   'showTm': '135',
#   'genres': '드라마',
#   'directors': '브래들리 쿠퍼',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '브래들리 쿠퍼',
#     'peopleNmEn': 'Bradley Cooper',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '레이디 가가', 'peopleNmEn': 'Lady Gaga', 'cast': '', 'castEn': ''},
#    {'peopleNm': '샘 엘리엇',
#     'peopleNmEn': 'Sam Elliott',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '그렉 그룬버그',
#     'peopleNmEn': 'Greg Grunberg',
#     'cast': '',
#     'castEn': ''}]},
#  '구스범스: 몬스터의 역습': {'movieCd': '20182693',
#   'movieNm': '구스범스: 몬스터의 역습',
#   'movieNmEn': 'Goosebumps 2: Haunted Halloween',
#   'movieNmOg': '',
#   'openDt': '20181107',
#   'showTm': '89',
#   'genres': '판타지',
#   'directors': '아리 산델',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '잭 블랙',
#     'peopleNmEn': 'Jack Black',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '켄 정', 'peopleNmEn': 'Ken Jeong', 'cast': '', 'castEn': ''}]},
#  '신비한 동물들과 그린델왈드의 범죄': {'movieCd': '20176814',
#   'movieNm': '신비한 동물들과 그린델왈드의 범죄',
#   'movieNmEn': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'movieNmOg': 'FANTASTIC BEASTS THE CRIMES OF GRINDELWALD',
#   'openDt': '20181114',
#   'showTm': '133',
#   'genres': '판타지',
#   'directors': '데이빗 예이츠',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '에디 레드메인',
#     'peopleNmEn': 'Eddie Redmayne',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '캐서린 워터스턴',
#     'peopleNmEn': 'Katherine Waterston',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '앨리슨 수돌',
#     'peopleNmEn': 'Alison Sudol',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '댄 포글러', 'peopleNmEn': 'Dan Fogler', 'cast': '', 'castEn': ''},
#    {'peopleNm': '에즈라 밀러',
#     'peopleNmEn': 'Ezra Miller',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '주드 로', 'peopleNmEn': 'Jude Law', 'cast': '', 'castEn': ''},
#    {'peopleNm': '조니 뎁', 'peopleNmEn': 'Johnny Depp', 'cast': '', 'castEn': ''},
#    {'peopleNm': '칼럼 터너',
#     'peopleNmEn': 'Callum Turner',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '조 크라비츠',
#     'peopleNmEn': 'Zoe Kravitz',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '수현', 'peopleNmEn': 'Claudia KIM', 'cast': '', 'castEn': ''}]},
#  '번 더 스테이지: 더 무비': {'movieCd': '20183050',
#   'movieNm': '번 더 스테이지: 더 무비',
#   'movieNmEn': 'Burn the Stage: the Movie',
#   'movieNmOg': '',
#   'openDt': '20181115',
#   'showTm': '82',
#   'genres': '기타',
#   'directors': '박준수',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '김남준', 'peopleNmEn': 'RM', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김석진', 'peopleNmEn': 'JIN', 'cast': '', 'castEn': ''},
#    {'peopleNm': '민윤기', 'peopleNmEn': 'SUGA', 'cast': '', 'castEn': ''},
#    {'peopleNm': '정호석', 'peopleNmEn': 'J-HOPE', 'cast': '', 'castEn': ''},
#    {'peopleNm': '박지민', 'peopleNmEn': 'JIMIN', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김태형', 'peopleNmEn': 'V', 'cast': '', 'castEn': ''},
#    {'peopleNm': '전정국', 'peopleNmEn': 'JUNGKOOK', 'cast': '', 'castEn': ''}]},
#  '성난황소': {'movieCd': '20184481',
#   'movieNm': '성난황소',
#   'movieNmEn': 'Unstoppable',
#   'movieNmOg': '',
#   'openDt': '20181122',
#   'showTm': '115',
#   'genres': '범죄',
#   'directors': '김민호',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '마동석',
#     'peopleNmEn': 'Don LEE',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '송지효', 'peopleNmEn': 'SONG Ji-hyo', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김성오', 'peopleNmEn': 'KIM Sung-oh', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김민재', 'peopleNmEn': 'KIM Min-jae', 'cast': '', 'castEn': ''},
#    {'peopleNm': '박지환', 'peopleNmEn': 'PARK Ji-hwan', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이동진', 'peopleNmEn': '', 'cast': '몽타주 피해자1', 'castEn': ''},
#    {'peopleNm': '이세영', 'peopleNmEn': '', 'cast': '서빙녀3', 'castEn': ''},
#    {'peopleNm': '박혜림', 'peopleNmEn': '', 'cast': '면접녀1', 'castEn': ''},
#    {'peopleNm': '김재철', 'peopleNmEn': '', 'cast': '대리인', 'castEn': ''},
#    {'peopleNm': '이연주', 'peopleNmEn': '', 'cast': '요양원 간호사1', 'castEn': ''}]},
#  '출국': {'movieCd': '20182935',
#   'movieNm': '출국',
#   'movieNmEn': 'Unfinished',
#   'movieNmOg': '',
#   'openDt': '20181114',
#   'showTm': '104',
#   'genres': '드라마',
#   'directors': '노규엽',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '이범수',
#     'peopleNmEn': 'LEE Beom-su',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '연우진', 'peopleNmEn': 'YEON Woo-jin', 'cast': '', 'castEn': ''},
#    {'peopleNm': '박혁권',
#     'peopleNmEn': 'PARK Hyuk-kwon',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '박주미', 'peopleNmEn': 'PARK Ju-mi', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이현정', 'peopleNmEn': '', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이종혁',
#     'peopleNmEn': 'LEE Jong-hyuk',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '이동훈', 'peopleNmEn': '', 'cast': '최과장요원6', 'castEn': ''}]},
#  '너의 췌장을 먹고 싶어': {'movieCd': '20186822',
#   'movieNm': '너의 췌장을 먹고 싶어',
#   'movieNmEn': 'I want to eat your pancreas',
#   'movieNmOg': '君の膵臓をたべたい',
#   'openDt': '20181115',
#   'showTm': '109',
#   'genres': '애니메이션',
#   'directors': '우시지마 신이치로',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '타카스기 마히로',
#     'peopleNmEn': 'Mahiro Takasugi',
#     'cast': '나 (목소리)',
#     'castEn': ''},
#    {'peopleNm': '린', 'peopleNmEn': 'Lynn', 'cast': '사쿠라 (목소리)', 'castEn': ''},
#    {'peopleNm': '후지이 유키요',
#     'peopleNmEn': 'Yukiyo Fujii',
#     'cast': '쿄코 (목소리)',
#     'castEn': ''},
#    {'peopleNm': '후쿠시마 준',
#     'peopleNmEn': 'Jun Fukushima',
#     'cast': '껌군 (목소리)',
#     'castEn': ''}]},
#  '해피 투게더': {'movieCd': '20189869',
#   'movieNm': '해피 투게더',
#   'movieNmEn': 'Happy Together',
#   'movieNmOg': '',
#   'openDt': '20181115',
#   'showTm': '110',
#   'genres': '드라마',
#   'directors': '김정환',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '박성웅',
#     'peopleNmEn': 'PARK Sung-woong',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '송새벽',
#     'peopleNmEn': 'SONG Sae-byeok',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '최로운', 'peopleNmEn': '', 'cast': '', 'castEn': ''},
#    {'peopleNm': '한상혁',
#     'peopleNmEn': 'HAN Sang-hyuk',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '권해효',
#     'peopleNmEn': 'KWON Hae-hyo',
#     'cast': '',
#     'castEn': ''}]},
#  '베일리 어게인': {'movieCd': '20183073',
#   'movieNm': '베일리 어게인',
#   'movieNmEn': "A Dog's Purpose",
#   'movieNmOg': '',
#   'openDt': '20181122',
#   'showTm': '100',
#   'genres': '어드벤처',
#   'directors': '라세 할스트롬',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '조시 게드',
#     'peopleNmEn': 'Josh Gad',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '데니스 퀘이드',
#     'peopleNmEn': 'Dennis Quaid',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '브릿 로버트슨',
#     'peopleNmEn': 'Britt Robertson',
#     'cast': '',
#     'castEn': ''}]},
#  '툴리': {'movieCd': '20182669',
#   'movieNm': '툴리',
#   'movieNmEn': 'TULLY',
#   'movieNmOg': '',
#   'openDt': '20181122',
#   'showTm': '95',
#   'genres': '드라마',
#   'directors': '제이슨 라이트맨',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '샤를리즈 테론',
#     'peopleNmEn': 'Charlize Theron',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '맥켄지 데이비스',
#     'peopleNmEn': 'Mackenzie Davis',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '마크 듀플라스',
#     'peopleNmEn': 'Mark Duplass',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '론 리빙스턴',
#     'peopleNmEn': 'Ron Livingston',
#     'cast': '',
#     'castEn': ''}]},
#  '국가부도의 날': {'movieCd': '20177552',
#   'movieNm': '국가부도의 날',
#   'movieNmEn': 'Default',
#   'movieNmOg': '',
#   'openDt': '20181128',
#   'showTm': '114',
#   'genres': '드라마',
#   'directors': '최국희',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '김혜수',
#     'peopleNmEn': 'KIM Hye-soo',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '유아인', 'peopleNmEn': 'YOO Ah-in', 'cast': '', 'castEn': ''},
#    {'peopleNm': '허준호', 'peopleNmEn': 'HUH Joon-ho', 'cast': '', 'castEn': ''},
#    {'peopleNm': '조우진', 'peopleNmEn': 'JO Woo-jin', 'cast': '', 'castEn': ''},
#    {'peopleNm': '뱅상 카셀',
#     'peopleNmEn': 'Vincent Cassel',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '이원희',
#     'peopleNmEn': '',
#     'cast': '아줌마 상담 고려종금 직원',
#     'castEn': ''},
#    {'peopleNm': '이은주', 'peopleNmEn': '', 'cast': '어린 시현&갑수 모', 'castEn': ''}]},
#  '후드': {'movieCd': '20181905',
#   'movieNm': '후드',
#   'movieNmEn': 'Robin Hood',
#   'movieNmOg': '',
#   'openDt': '20181128',
#   'showTm': '116',
#   'genres': '어드벤처',
#   'directors': '오토 바서스트',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '태런 에저튼',
#     'peopleNmEn': 'Taron Egerton',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '제이미 폭스',
#     'peopleNmEn': 'Jamie Foxx',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '벤 멘델슨',
#     'peopleNmEn': 'Ben Mendelsohn',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '제이미 도넌',
#     'peopleNmEn': 'Jamie Dornan',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '이브 휴슨', 'peopleNmEn': 'Eve Hewson', 'cast': '', 'castEn': ''},
#    {'peopleNm': '폴 W.S. 앤더슨',
#     'peopleNmEn': 'Paul W.S. Anderson',
#     'cast': '',
#     'castEn': ''}]},
#  '거미줄에 걸린 소녀': {'movieCd': '20183007',
#   'movieNm': '거미줄에 걸린 소녀',
#   'movieNmEn': 'THE GIRL IN THE SPIDER’S WEB',
#   'movieNmOg': '',
#   'openDt': '20181128',
#   'showTm': '115',
#   'genres': '액션',
#   'directors': '페드 알바레즈',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '클레어 포이',
#     'peopleNmEn': 'Claire Foy',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '실비아 획스',
#     'peopleNmEn': 'Sylvia Hoeks',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '스베리르 구드나손',
#     'peopleNmEn': 'Sverrir Gudnason',
#     'cast': '',
#     'castEn': ''}]},
#  '투 프렌즈': {'movieCd': '20182966',
#   'movieNm': '투 프렌즈',
#   'movieNmEn': 'TWO TAILS',
#   'movieNmOg': '',
#   'openDt': '20181129',
#   'showTm': '74',
#   'genres': '애니메이션',
#   'directors': '빅터 아즈에프',
#   'watchGradeNm': '전체관람가',
#   'actors': []},
#  '도어락': {'movieCd': '20179230',
#   'movieNm': '도어락',
#   'movieNmEn': 'Door Lock',
#   'movieNmOg': '',
#   'openDt': '20181205',
#   'showTm': '101',
#   'genres': '스릴러',
#   'directors': '이권',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '공효진',
#     'peopleNmEn': 'KONG Hyo-jin',
#     'cast': '조경민',
#     'castEn': ''},
#    {'peopleNm': '김예원',
#     'peopleNmEn': 'KIM Ye-won',
#     'cast': '오효주',
#     'castEn': ''},
#    {'peopleNm': '김성오',
#     'peopleNmEn': 'KIM Sung-oh',
#     'cast': '이형사',
#     'castEn': ''},
#    {'peopleNm': '조복래', 'peopleNmEn': 'JO Bok-rae', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이가섭', 'peopleNmEn': 'LEE Ga-sub', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이천희',
#     'peopleNmEn': 'LEE Chun-hee',
#     'cast': '',
#     'castEn': ''}]},
#  '호두까기 인형과 4개의 왕국': {'movieCd': '20189843',
#   'movieNm': '호두까기 인형과 4개의 왕국',
#   'movieNmEn': 'The Nutcracker and the Four Realms',
#   'movieNmOg': '',
#   'openDt': '20181206',
#   'showTm': '99',
#   'genres': '판타지',
#   'directors': '라세 할스트롬',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '키이라 나이틀리',
#     'peopleNmEn': 'Keira Knightley',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '매켄지 포이',
#     'peopleNmEn': 'Mackenzie Foy',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '헬렌 미렌',
#     'peopleNmEn': 'Helen Mirren',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '모건 프리먼',
#     'peopleNmEn': 'Morgan Freeman',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '매튜 맥퍼딘',
#     'peopleNmEn': 'Matthew Macfadyen',
#     'cast': '',
#     'castEn': ''}]},
#  '모털 엔진': {'movieCd': '20178825',
#   'movieNm': '모털 엔진',
#   'movieNmEn': 'Mortal Engines',
#   'movieNmOg': '',
#   'openDt': '20181205',
#   'showTm': '128',
#   'genres': '액션',
#   'directors': '크리스찬 리버스',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '헤라 힐마',
#     'peopleNmEn': 'Hera Hilmar',
#     'cast': '헤스터 쇼',
#     'castEn': ''},
#    {'peopleNm': '로버트 시한',
#     'peopleNmEn': 'Robert Sheehan',
#     'cast': '톰 내츠워디',
#     'castEn': ''},
#    {'peopleNm': '휴고 위빙',
#     'peopleNmEn': 'Hugo Weaving',
#     'cast': '테데우스 발렌타인',
#     'castEn': ''},
#    {'peopleNm': '지혜', 'peopleNmEn': '', 'cast': '안나', 'castEn': ''},
#    {'peopleNm': '스티븐 랭',
#     'peopleNmEn': 'Stephen Lang',
#     'cast': '슈라이크',
#     'castEn': ''}]},
#  '런닝맨 : 풀룰루의 역습': {'movieCd': '20183745',
#   'movieNm': '런닝맨 : 풀룰루의 역습',
#   'movieNmEn': 'Running Man',
#   'movieNmOg': '',
#   'openDt': '20181205',
#   'showTm': '66',
#   'genres': '애니메이션',
#   'directors': '윤준상',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '김서영',
#     'peopleNmEn': 'KIM Seo-young',
#     'cast': '리우 목소리',
#     'castEn': ''},
#    {'peopleNm': '권창욱', 'peopleNmEn': '', 'cast': '쿠가 목소리', 'castEn': ''},
#    {'peopleNm': '엄상현',
#     'peopleNmEn': 'UM Sang-hyun',
#     'cast': '롱키 목소리',
#     'castEn': ''},
#    {'peopleNm': '김연우', 'peopleNmEn': '', 'cast': '미요 목소리', 'castEn': ''},
#    {'peopleNm': '강시현', 'peopleNmEn': '', 'cast': '포포 목소리', 'castEn': ''},
#    {'peopleNm': '전태열', 'peopleNmEn': '', 'cast': '팔라 목소리', 'castEn': ''}]},
#  '스파이더맨: 뉴 유니버스': {'movieCd': '20183238',
#   'movieNm': '스파이더맨: 뉴 유니버스',
#   'movieNmEn': 'Spider-Man: Into the Spider-Verse',
#   'movieNmOg': '',
#   'openDt': '20181212',
#   'showTm': '116',
#   'genres': '애니메이션',
#   'directors': '밥 퍼시케티',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '샤메익 무어',
#     'peopleNmEn': 'Shameik Moore',
#     'cast': '마일스 모랄레스',
#     'castEn': ''},
#    {'peopleNm': '헤일리 스테인펠드',
#     'peopleNmEn': 'Hailee Steinfeld',
#     'cast': '스파이더 그웬',
#     'castEn': ''},
#    {'peopleNm': '니콜라스 케이지',
#     'peopleNmEn': 'Nicolas Cage ',
#     'cast': '스파이더맨 누아르',
#     'castEn': ''},
#    {'peopleNm': '제이크 존슨',
#     'peopleNmEn': 'Jake Johnson',
#     'cast': '피터 B. 파커',
#     'castEn': ''},
#    {'peopleNm': '리브 슈라이버',
#     'peopleNmEn': 'Liev Schreiber',
#     'cast': '킹핀',
#     'castEn': ''},
#    {'peopleNm': '마허샬라 알리',
#     'peopleNmEn': 'Mahershala Ali',
#     'cast': '애런 데이비스',
#     'castEn': ''}]},
#  '부탁 하나만 들어줘': {'movieCd': '20182082',
#   'movieNm': '부탁 하나만 들어줘',
#   'movieNmEn': 'A Simple Favor',
#   'movieNmOg': '',
#   'openDt': '20181212',
#   'showTm': '116',
#   'genres': '스릴러',
#   'directors': '폴 페이그',
#   'watchGradeNm': '청소년관람불가',
#   'actors': [{'peopleNm': '블레이크 라이블리',
#     'peopleNmEn': 'Blake Lively',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '안나 켄드릭',
#     'peopleNmEn': 'Anna Kendrick',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '헨리 골딩',
#     'peopleNmEn': 'Henry Golding',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '앤드류 라넬스',
#     'peopleNmEn': 'Andrew Rannells',
#     'cast': '',
#     'castEn': ''}]},
#  '스윙키즈': {'movieCd': '20175547',
#   'movieNm': '스윙키즈',
#   'movieNmEn': 'Swing Kids',
#   'movieNmOg': '',
#   'openDt': '20181219',
#   'showTm': '133',
#   'genres': '드라마',
#   'directors': '강형철',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '도경수',
#     'peopleNmEn': 'DOH Kyung-soo',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '박혜수', 'peopleNmEn': '', 'cast': '', 'castEn': ''},
#    {'peopleNm': '자레드 그라임스',
#     'peopleNmEn': 'Jared Grimes',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '오정세', 'peopleNmEn': 'OH Jung-se', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김민호', 'peopleNmEn': '', 'cast': '', 'castEn': ''}]},
#  '아쿠아맨': {'movieCd': '20180290',
#   'movieNm': '아쿠아맨',
#   'movieNmEn': 'AQUAMAN',
#   'movieNmOg': '',
#   'openDt': '20181219',
#   'showTm': '143',
#   'genres': '액션',
#   'directors': '제임스 완',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '제이슨 모모아',
#     'peopleNmEn': 'Jason Momoa',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '앰버 허드',
#     'peopleNmEn': 'Amber Heard',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '니콜 키드먼',
#     'peopleNmEn': 'Nicole Kidman',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '패트릭 윌슨',
#     'peopleNmEn': 'Patrick Wilson',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '윌렘 데포',
#     'peopleNmEn': 'Willem Dafoe',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '돌프 룬드그렌',
#     'peopleNmEn': 'Dolph Lundgren',
#     'cast': '',
#     'castEn': ''}]},
#  '마약왕': {'movieCd': '20168773',
#   'movieNm': '마약왕',
#   'movieNmEn': 'The Drug King',
#   'movieNmOg': '',
#   'openDt': '20181219',
#   'showTm': '139',
#   'genres': '범죄',
#   'directors': '우민호',
#   'watchGradeNm': '청소년관람불가',
#   'actors': [{'peopleNm': '송강호',
#     'peopleNmEn': 'SONG Kang-ho',
#     'cast': '이두삼',
#     'castEn': ''},
#    {'peopleNm': '조정석',
#     'peopleNmEn': 'JO Jung-suk',
#     'cast': '김인구',
#     'castEn': ''},
#    {'peopleNm': '배두나',
#     'peopleNmEn': 'BAE Doo-na',
#     'cast': '김정아',
#     'castEn': ''},
#    {'peopleNm': '김소진',
#     'peopleNmEn': 'KIM So-jin',
#     'cast': '성숙경',
#     'castEn': ''},
#    {'peopleNm': '김대명',
#     'peopleNmEn': 'KIM Dae-myeong',
#     'cast': '이두환',
#     'castEn': ''},
#    {'peopleNm': '이희준',
#     'peopleNmEn': 'LEE Hee-jun',
#     'cast': '최진필',
#     'castEn': ''},
#    {'peopleNm': '조우진',
#     'peopleNmEn': 'JO Woo-jin',
#     'cast': '조성강',
#     'castEn': ''},
#    {'peopleNm': '이성민',
#     'peopleNmEn': 'LEE Sung-min',
#     'cast': '서반장',
#     'castEn': ''},
#    {'peopleNm': '김홍파',
#     'peopleNmEn': 'KIM Hong-pa',
#     'cast': '백교수',
#     'castEn': ''}]},
#  '그린치': {'movieCd': '20182421',
#   'movieNm': '그린치',
#   'movieNmEn': 'The Grinch',
#   'movieNmOg': '',
#   'openDt': '20181219',
#   'showTm': '89',
#   'genres': '애니메이션',
#   'directors': '스콧 모시어',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '베네딕트 컴버배치',
#     'peopleNmEn': 'Benedict Cumberbatch',
#     'cast': '',
#     'castEn': ''}]},
#  '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~': {'movieCd': '20183479',
#   'movieNm': '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~',
#   'movieNmEn': 'Crayon Shin-chan: Burst Serving! Kung Fu Boys - Ramen Rebellion',
#   'movieNmOg': '',
#   'openDt': '20181219',
#   'showTm': '103',
#   'genres': '애니메이션',
#   'directors': '타카하시 와타루',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '박영남',
#     'peopleNmEn': 'PARK Yoeng-nam',
#     'cast': '짱구 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '강희선',
#     'peopleNmEn': 'GANG Hui-seon',
#     'cast': '엄마/맹구 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '김환진',
#     'peopleNmEn': 'KIM Hwan-chin',
#     'cast': '아빠 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '여민정',
#     'peopleNmEn': '',
#     'cast': '짱아/철수 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '정유미',
#     'peopleNmEn': '',
#     'cast': '흰둥이/유리 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '정혜옥', 'peopleNmEn': '', 'cast': '훈이 (한국어 목소리)', 'castEn': ''},
#    {'peopleNm': '이용신',
#     'peopleNmEn': 'Lee Yong-shin',
#     'cast': '채성아/민희 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '한채언',
#     'peopleNmEn': '',
#     'cast': '나미리/서점주인 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '윤여진',
#     'peopleNmEn': '',
#     'cast': '차은주 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '홍범기',
#     'peopleNmEn': 'HONG Beom-gi',
#     'cast': '정훈 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '정혜원', 'peopleNmEn': '', 'cast': '용숙 (한국어 목소리)', 'castEn': ''},
#    {'peopleNm': '박리나',
#     'peopleNmEn': 'PARK Ri-na',
#     'cast': '은혜/희경 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '김율',
#     'peopleNmEn': '',
#     'cast': '마리/광자 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '이호산',
#     'peopleNmEn': 'LEE Ho-san',
#     'cast': '오수 (한국어 목소리)',
#     'castEn': ''},
#    {'peopleNm': '김현심',
#     'peopleNmEn': '',
#     'cast': '옆집아줌마 (한국어 목소리)',
#     'castEn': ''}]},
#  '극장판 포켓몬스터 모두의 이야기': {'movieCd': '20183375',
#   'movieNm': '극장판 포켓몬스터 모두의 이야기',
#   'movieNmEn': 'Pokemon the Movie: The Power of Us',
#   'movieNmOg': '劇場版ポケットモンスター みんなの物語',
#   'openDt': '20181219',
#   'showTm': '98',
#   'genres': '애니메이션',
#   'directors': '야지마 테츠오',
#   'watchGradeNm': '전체관람가',
#   'actors': []},
#  '범블비': {'movieCd': '20186281',
#   'movieNm': '범블비',
#   'movieNmEn': 'Bumblebee',
#   'movieNmOg': '',
#   'openDt': '20181225',
#   'showTm': '113',
#   'genres': '액션',
#   'directors': '트래비스 나이트',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '헤일리 스테인펠드',
#     'peopleNmEn': 'Hailee Steinfeld',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '파멜라 애들론',
#     'peopleNmEn': 'Pamela Adlon',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '존 시나', 'peopleNmEn': 'John Cena', 'cast': '', 'castEn': ''},
#    {'peopleNm': '피터 쿨렌',
#     'peopleNmEn': 'Peter Cullen',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '케네스 최',
#     'peopleNmEn': 'Kenneth Choi',
#     'cast': '',
#     'castEn': ''}]},
#  'PMC: 더 벙커': {'movieCd': '20170658',
#   'movieNm': 'PMC: 더 벙커',
#   'movieNmEn': 'Take Point',
#   'movieNmOg': '',
#   'openDt': '20181226',
#   'showTm': '124',
#   'genres': '액션',
#   'directors': '김병우',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '하정우',
#     'peopleNmEn': 'HA Jung-woo',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '이선균', 'peopleNmEn': 'LEE Sun-kyun', 'cast': '', 'castEn': ''},
#    {'peopleNm': '제니퍼 엘',
#     'peopleNmEn': 'Jennifer Ehle',
#     'cast': '',
#     'castEn': ''}]},
#  '점박이 한반도의 공룡2 : 새로운 낙원': {'movieCd': '20183785',
#   'movieNm': '점박이 한반도의 공룡2 : 새로운 낙원',
#   'movieNmEn': '',
#   'movieNmOg': '',
#   'openDt': '20181225',
#   'showTm': '93',
#   'genres': '애니메이션',
#   'directors': '한상호',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '박희순',
#     'peopleNmEn': 'PARK Hee-soon',
#     'cast': '점박이 목소리',
#     'castEn': ''},
#    {'peopleNm': '라미란',
#     'peopleNmEn': 'RA Mi-ran',
#     'cast': '송곳니 목소리',
#     'castEn': ''},
#    {'peopleNm': '김성균',
#     'peopleNmEn': 'KIM Sung-kyun',
#     'cast': '싸이 목소리',
#     'castEn': ''}]},
#  '주먹왕 랄프 2: 인터넷 속으로': {'movieCd': '20189463',
#   'movieNm': '주먹왕 랄프 2: 인터넷 속으로',
#   'movieNmEn': 'Ralph Breaks the Internet',
#   'movieNmOg': '',
#   'openDt': '20190103',
#   'showTm': '112',
#   'genres': '애니메이션',
#   'directors': '리치 무어',
#   'watchGradeNm': '전체관람가',
#   'actors': [{'peopleNm': '존 C. 라일리',
#     'peopleNmEn': 'John C. Reilly',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '사라 실버맨',
#     'peopleNmEn': 'Sarah Silverman',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '맨디 무어',
#     'peopleNmEn': 'Mandy Moore',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '크리스틴 벨',
#     'peopleNmEn': 'Kristen Bell',
#     'cast': '',
#     'castEn': ''}]},
#  '언니': {'movieCd': '20184187',
#   'movieNm': '언니',
#   'movieNmEn': 'No Mercy',
#   'movieNmOg': '',
#   'openDt': '20190101',
#   'showTm': '93',
#   'genres': '액션',
#   'directors': '임경택',
#   'watchGradeNm': '청소년관람불가',
#   'actors': [{'peopleNm': '이시영',
#     'peopleNmEn': 'LEE Si-young',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '박세완', 'peopleNmEn': 'PARK Se-wan', 'cast': '', 'castEn': ''},
#    {'peopleNm': '이준혁', 'peopleNmEn': 'LEE Jun-hyuk', 'cast': '', 'castEn': ''},
#    {'peopleNm': '최진호',
#     'peopleNmEn': 'CHOI Jin-ho',
#     'cast': '',
#     'castEn': ''}]},
#  '말모이': {'movieCd': '20184105',
#   'movieNm': '말모이',
#   'movieNmEn': 'MAL·MO·E: The Secret Mission',
#   'movieNmOg': '',
#   'openDt': '20190109',
#   'showTm': '135',
#   'genres': '드라마',
#   'directors': '엄유나',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '유해진',
#     'peopleNmEn': 'YOO Hae-jin',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '윤계상',
#     'peopleNmEn': 'YOON Kye-sang',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '김홍파', 'peopleNmEn': 'KIM Hong-pa', 'cast': '', 'castEn': ''},
#    {'peopleNm': '우현', 'peopleNmEn': 'WOO Hyun', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김태훈', 'peopleNmEn': 'KIM Tae-hun', 'cast': '', 'castEn': ''},
#    {'peopleNm': '김선영',
#     'peopleNmEn': 'KIM Sun-young',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '민진웅',
#     'peopleNmEn': 'MIN Jin-woong',
#     'cast': '',
#     'castEn': ''}]},
#  '내안의 그놈': {'movieCd': '20176251',
#   'movieNm': '내안의 그놈',
#   'movieNmEn': 'Inside me',
#   'movieNmOg': '',
#   'openDt': '20190109',
#   'showTm': '122',
#   'genres': '판타지',
#   'directors': '강효진',
#   'watchGradeNm': '15세이상관람가',
#   'actors': [{'peopleNm': '박성웅',
#     'peopleNmEn': 'PARK Sung-woong',
#     'cast': '판수',
#     'castEn': ''},
#    {'peopleNm': '진영', 'peopleNmEn': '', 'cast': '동현', 'castEn': ''},
#    {'peopleNm': '라미란', 'peopleNmEn': 'RA Mi-ran', 'cast': '미선', 'castEn': ''},
#    {'peopleNm': '이수민', 'peopleNmEn': '', 'cast': '현정', 'castEn': ''},
#    {'peopleNm': '이준혁',
#     'peopleNmEn': 'LEE Jun-hyeok',
#     'cast': '만철',
#     'castEn': ''},
#    {'peopleNm': '김광규',
#     'peopleNmEn': 'KIM Kwang-gyoo',
#     'cast': '종기',
#     'castEn': ''},
#    {'peopleNm': '민지아', 'peopleNmEn': 'MIN Jee-a', 'cast': '서연', 'castEn': ''},
#    {'peopleNm': '윤경호', 'peopleNmEn': '', 'cast': '양사장', 'castEn': ''},
#    {'peopleNm': '김현목',
#     'peopleNmEn': 'KIM Hyun-mok',
#     'cast': '재익',
#     'castEn': ''},
#    {'peopleNm': '권혁범', 'peopleNmEn': '', 'cast': '철호', 'castEn': ''},
#    {'peopleNm': '이호수', 'peopleNmEn': '', 'cast': '태욱', 'castEn': ''},
#    {'peopleNm': '김상겸', 'peopleNmEn': '', 'cast': '판수조직원2', 'castEn': ''}]},
#  '극장판 공룡메카드: 타이니소어의 섬': {'movieCd': '20183915',
#   'movieNm': '극장판 공룡메카드: 타이니소어의 섬',
#   'movieNmEn': '',
#   'movieNmOg': '',
#   'openDt': '20190110',
#   'showTm': '70',
#   'genres': '애니메이션',
#   'directors': '최신규',
#   'watchGradeNm': '전체관람가',
#   'actors': []},
#  '그린 북': {'movieCd': '20184574',
#   'movieNm': '그린 북',
#   'movieNmEn': 'Green Book',
#   'movieNmOg': '',
#   'openDt': '20190109',
#   'showTm': '130',
#   'genres': '드라마',
#   'directors': '피터 패럴리',
#   'watchGradeNm': '12세이상관람가',
#   'actors': [{'peopleNm': '비고 모텐슨',
#     'peopleNmEn': 'Viggo Mortensen',
#     'cast': '',
#     'castEn': ''},
#    {'peopleNm': '마허샬라 알리',
#     'peopleNmEn': 'Mahershala Ali',
#     'cast': '',
#     'castEn': ''}]}}

# %%
fd = open('movie.csv', 'w+', encoding='utf-8')

writer_fd = csv.writer(fd)

writer_fd.writerow(['영화 코드', '영화명', '영문명', '원문명', '개봉일', '러닝타임', '장르', '감독', '등급', '배우1', '배우2', '배우3'])

f.close()

# fd = open('movie.csv', 'a+', encoding='utf-8')
# writer_fd = csv.writer(fd)
# for k in detail_result:
#     if len(detail_result[k]['actors']) >= 3:
#         writer_fd.writerow(
#             [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], detail_result[k]['actors'][0]['peopleNm'], detail_result[k]['actors'][1]['peopleNm'], detail_result[k]['actors'][2]['peopleNm'] ]
#         )
#     elif len(detail_result[k]['actors']) == 2:
#         writer_fd.writerow(
#             [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], detail_result[k]['actors'][0]['peopleNm'], detail_result[k]['actors'][1]['peopleNm'] ]
#         )
#     elif len(detail_result[k]['actors']) == 1:
#         writer_fd.writerow(
#             [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], detail_result[k]['actors'][0]['peopleNm'] ]
#         )
#     elif len(detail_result[k]['actors']) == 0:
#         writer_fd.writerow(
#             [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], '' ]
#         )

# f.close()

# %%
fd = open('movie.csv', 'a+', encoding='utf-8', newline = '')
writer_fd = csv.writer(fd)
for k in detail_result:
    if len(detail_result[k]['actors']) >= 3:
        writer_fd.writerow(
            [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], detail_result[k]['actors'][0]['peopleNm'], detail_result[k]['actors'][1]['peopleNm'], detail_result[k]['actors'][2]['peopleNm'] ]
        )
    elif len(detail_result[k]['actors']) == 2:
        writer_fd.writerow(
            [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], detail_result[k]['actors'][0]['peopleNm'], detail_result[k]['actors'][1]['peopleNm'] ]
        )
    elif len(detail_result[k]['actors']) == 1:
        writer_fd.writerow(
            [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], detail_result[k]['actors'][0]['peopleNm'] ]
        )
    elif len(detail_result[k]['actors']) == 0:
        writer_fd.writerow(
            [detail_result[k]['movieCd'], detail_result[k]['movieNm'], detail_result[k]['movieNmEn'], detail_result[k]['movieNmOg'], detail_result[k]['openDt'], detail_result[k]['showTm'], detail_result[k]['genres'], detail_result[k]['directors'], detail_result[k]['watchGradeNm'], '' ]
        )

f.close()

# %%
movies = []
for i in detail_result:
    movies += [i]
    
movies
# Out:
# ['완벽한 타인',
#  '보헤미안 랩소디',
#  '동네사람들',
#  '바울',
#  '창궐',
#  '해리포터와 마법사의 돌',
#  '여곡성',
#  '벽 속에 숨은 마법시계',
#  '스타 이즈 본',
#  '구스범스: 몬스터의 역습',
#  '신비한 동물들과 그린델왈드의 범죄',
#  '번 더 스테이지: 더 무비',
#  '성난황소',
#  '출국',
#  '너의 췌장을 먹고 싶어',
#  '해피 투게더',
#  '베일리 어게인',
#  '툴리',
#  '국가부도의 날',
#  '후드',
#  '거미줄에 걸린 소녀',
#  '투 프렌즈',
#  '도어락',
#  '호두까기 인형과 4개의 왕국',
#  '모털 엔진',
#  '런닝맨 : 풀룰루의 역습',
#  '스파이더맨: 뉴 유니버스',
#  '부탁 하나만 들어줘',
#  '스윙키즈',
#  '아쿠아맨',
#  '마약왕',
#  '그린치',
#  '극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~',
#  '극장판 포켓몬스터 모두의 이야기',
#  '범블비',
#  'PMC: 더 벙커',
#  '점박이 한반도의 공룡2 : 새로운 낙원',
#  '주먹왕 랄프 2: 인터넷 속으로',
#  '언니',
#  '말모이',
#  '내안의 그놈',
#  '극장판 공룡메카드: 타이니소어의 섬',
#  '그린 북']

# %%
from time import sleep 

naver_uri = 'https://openapi.naver.com/v1/search/movie.json?query='

client_id = 'jaABkZc1n4M0x7c5kCcP'
client_secret = 'OJr0EvId4F'
headers = {
    'X-Naver-Client-Id': client_id, 
    'X-Naver-Client-Secret': client_secret

}

thump = []
movie_info = {}
for y in range(len(movies)):
    res = requests.get(naver_uri + movies[y], headers = headers)
    data = res.json()
    movie_info[data['items'][0]['title']] = {
        'code' : data['items'][0]
        'link' : data['items'][0]['link'],
        'image' : data['items'][0]['image'],
        'userRating': data['items'][0]['userRating']
    }
    sleep(0.05)

# %%
movie_info
# Out:
# {'<b>완벽한 타인</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167638',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167638_P71_133542.jpg',
#   'userRating': '8.66'},
#  '<b>보헤미안 랩소디</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=156464',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1564/156464_P49_182103.jpg',
#   'userRating': '9.47'},
#  '<b>동네사람들</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=166610',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1666/166610_P58_154049.jpg',
#   'userRating': '5.52'},
#  '<b>바울</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=173692',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1736/173692_P12_102159.jpg',
#   'userRating': '9.17'},
#  '<b>창궐</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=160487',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1604/160487_P48_113750.jpg',
#   'userRating': '5.13'},
#  '<b>해리 포터와 마법사의 돌</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=30688',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/0306/30688_P28_142632.jpg',
#   'userRating': '9.23'},
#  '<b>여곡성</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171750',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1717/171750_P05_173050.jpg',
#   'userRating': '4.31'},
#  '<b>벽 속에 숨은 마법시계</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164155',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164155_P03_122329.jpg',
#   'userRating': '6.15'},
#  '<b>스타 이즈 본</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=168050',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1680/168050_P19_100458.jpg',
#   'userRating': '9.15'},
#  '<b>구스범스: 몬스터의 역습</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172819',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1728/172819_P01_163303.jpg',
#   'userRating': '7.50'},
#  '<b>신비한 동물들과 그린델왈드의 범죄</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=154255',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1542/154255_P24_095824.jpg',
#   'userRating': '6.28'},
#  '<b>번 더 스테이지: 더 무비</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=176354',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1763/176354_P13_150227.jpg',
#   'userRating': '9.36'},
#  '<b>성난황소</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=174835',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1748/174835_P26_105639.jpg',
#   'userRating': '7.60'},
#  '<b>출국</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=179139',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1791/179139_P14_100455.jpg',
#   'userRating': '8.79'},
#  '<b>너의 췌장을 먹고 싶어</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=175318',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1753/175318_P15_105507.jpg',
#   'userRating': '8.31'},
#  '<b>해피 투게더</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164147',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164147_P46_165808.jpg',
#   'userRating': '7.70'},
#  '<b>베일리 어게인</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=144906',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1449/144906_P15_103017.jpg',
#   'userRating': '9.53'},
#  '<b>툴리</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=154653',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1546/154653_P12_102646.jpg',
#   'userRating': '8.80'},
#  '<b>국가부도의 날</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164192',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164192_P45_134107.jpg',
#   'userRating': '8.18'},
#  '<b>후드</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=144266',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1442/144266_P15_111933.jpg',
#   'userRating': '7.16'},
#  '<b>거미줄에 걸린 소녀</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=161868',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1618/161868_P24_151256.jpg',
#   'userRating': '8.55'},
#  '<b>투 프렌즈</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=179138',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1791/179138_P01_151818.jpg',
#   'userRating': '4.52'},
#  '<b>도어락</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171755',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1717/171755_P39_140011.jpg',
#   'userRating': '6.28'},
#  '<b>호두까기 인형과 4개의 왕국</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=158622',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1586/158622_P18_142307.jpg',
#   'userRating': '7.39'},
#  '<b>모털 엔진</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=156496',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1564/156496_P24_153246.jpg',
#   'userRating': '6.39'},
#  '<b>런닝맨 : 풀룰루의 역습</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180384',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180384_P14_152246.jpg',
#   'userRating': '7.75'},
#  '<b>스파이더맨: 뉴 유니버스</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171725',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1717/171725_P18_175530.jpg',
#   'userRating': '9.26'},
#  '<b>부탁 하나만 들어줘</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171452',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1714/171452_P19_174244.jpg',
#   'userRating': '7.87'},
#  '<b>스윙키즈</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164101',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164101_P62_155759.jpg',
#   'userRating': '8.49'},
#  '<b>아쿠아맨</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=151153',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1511/151153_P19_095147.jpg',
#   'userRating': '8.38'},
#  '<b>마약왕</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=157297',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1572/157297_P23_134212.jpg',
#   'userRating': '6.52'},
#  '<b>그린치</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=150688',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1506/150688_P30_101919.jpg',
#   'userRating': '8.36'},
#  '<b>극장판 짱구는 못말려: 아뵤! 쿵후 보이즈 ~라면 대란~</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172975',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1729/172975_P10_141815.jpg',
#   'userRating': '8.45'},
#  '<b>극장판 포켓몬스터 모두의 이야기</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=172187',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1721/172187_P19_110125.jpg',
#   'userRating': '9.04'},
#  '<b>범블비</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164139',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164139_P12_153521.jpg',
#   'userRating': '8.18'},
#  '<b>PMC: 더 벙커</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=166092',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1660/166092_P35_104446.jpg',
#   'userRating': '5.32'},
#  '<b>점박이 한반도의 공룡2 : 새로운 낙원</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180379',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180379_P32_111508.jpg',
#   'userRating': '9.18'},
#  '<b>주먹왕 랄프 2: 인터넷 속으로</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=152632',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1526/152632_P19_104759.jpg',
#   'userRating': '8.76'},
#  '<b>언니</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=152344',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1523/152344_P75_112734.jpg',
#   'userRating': '5.97'},
#  '<b>말모이</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=167699',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1676/167699_P40_175859.jpg',
#   'userRating': '9.03'},
#  '<b>내안의 그놈</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=164172',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1641/164172_P26_152224.jpg',
#   'userRating': '8.77'},
#  '<b>극장판 공룡메카드: 타이니소어의 섬</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=180372',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1803/180372_P16_101254.jpg',
#   'userRating': '9.19'},
#  '<b>그린 북</b>': {'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171539',
#   'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1715/171539_P26_135622.jpg',
#   'userRating': '9.66'}}

# %%
data
# Out:
# {'lastBuildDate': 'Fri, 18 Jan 2019 18:32:51 +0900',
#  'total': 1,
#  'start': 1,
#  'display': 1,
#  'items': [{'title': '<b>그린 북</b>',
#    'link': 'https://movie.naver.com/movie/bi/mi/basic.nhn?code=171539',
#    'image': 'https://ssl.pstatic.net/imgmovie/mdi/mit110/1715/171539_P26_135622.jpg',
#    'subtitle': 'Green Book',
#    'pubDate': '2018',
#    'director': '피터 패럴리|',
#    'actor': '비고 모텐슨|마허샬라 알리|',
#    'userRating': '9.66'}]}
